# %%
import pandas as pd
import numpy as np
import re
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.linear_model import LassoCV
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMRegressor

pd.set_option('display.max_columns', None)

# %%
file_path = "/home/dasun/Projects/Research/ICUG/NoteBooks/data/Data.xlsx"
sheet_name = "Sheet3"

df_raw = pd.read_excel(file_path, sheet_name=sheet_name)

# %%
data_new = df_raw.copy()
columns_to_drop = ['Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22', 'Name ', 'Birth place', 'Blood glucose']

data_new.drop(columns=columns_to_drop, inplace=True)

# %%
data_new.head()
# Out:
#    Gender   Age  Weight(kg)  Height(cm)  BMI(kg/m2)  Waist circumference  \
# 0     NaN   NaN         NaN         NaN         NaN                  NaN
# 1    Male  23.0        93.5       171.5       31.79                 99.1
# 2    Male  23.0        93.5       171.5       31.79                 99.1
# 3  Female  23.0        47.7       156.8       19.40                 69.7
# 4  Female  23.0        47.7       156.8       19.40                 69.7
#
#    Hip circumference  WC/HC Family history diabetics  \
# 0                NaN    NaN                      NaN
# 1              107.0   0.93                       No
# 2              107.0   0.93                       No
# 3               87.0   0.80                       No
# 4               87.0   0.80                       No
#
#                      Physical activity Health Problem Alcoholic Blood Group  \
# 0                                  NaN            NaN       NaN         NaN
# 1  Light ( Only Day-to-Day activities)             No     Never          A+
# 2  Light ( Only Day-to-Day activities)             No     Never          A+
# 3  Light ( Only Day-to-Day activities)             No     Never          A+
# 4  Light ( Only Day-to-Day activities)             No     Never          A+
#
#            Food Item    IAUC  Carb(g/100g)  Protien(g)      Fat(g)  \
# 0                NaN     NaN           NaN         NaN         NaN
# 1   Glucose Solution  2699.0          16.7           0           0
# 2  Rice-Super kernal  1425.0   81.7 ± 0.7a  3.7  ± 0.6  1.1  ± 0.2
# 3   Glucose Solution  2940.0          16.7           0           0
# 4  Rice-Red Fragrant  7208.0  79.3 ± 0.1bc  4.9  ± 0.2  1.8  ± 0.2
#
#   Moisture(%)  Ash Content Dietary Fiber
# 0         NaN          NaN           NaN
# 1        83.3            0             0
# 2  12.8 ± 0.3  0.7  ± 0.01    5.4 ± 0.2c
# 3        83.3            0             0
# 4  12.9 ± 0.3  1.1  ± 0.01    5.0 ± 0.2c
